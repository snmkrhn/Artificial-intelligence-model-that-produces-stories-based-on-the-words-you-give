# %% [markdown]
# <a href="https://www.kaggle.com/code/sinemkarahan/storygeneretor?scriptVersionId=224279277" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/tinystories-narrative-classification/validation.csv
# /kaggle/input/tinystories-narrative-classification/train.csv

# %%
import pandas as pd

# %%
df = pd.read_csv("/kaggle/input/tinystories-narrative-classification/train.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2119719 entries, 0 to 2119718
# Data columns (total 1 columns):
#  #   Column  Dtype
# ---  ------  -----
#  0   text    object
# dtypes: object(1)
# memory usage: 16.2+ MB

# %%
df.head()
# Out:
#                                                 text
# 0  One day, a little girl named Lily found a need...
# 1  Once upon a time, there was a little car named...
# 2  One day, a little fish named Fin was swimming ...
# 3  Once upon a time, in a land full of trees, the...
# 4  Once upon a time, there was a little girl name...

# %%
import pandas as pd

df = pd.read_csv("/kaggle/input/tinystories-narrative-classification/train.csv")
print(df.info())  # Veri türleri ve eksik veriler hakkında bilgi almak için
print(df.head())  # İlk birkaç satırı görüntülemek için
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2119719 entries, 0 to 2119718
# Data columns (total 1 columns):
#  #   Column  Dtype
# ---  ------  -----
#  0   text    object
# dtypes: object(1)
# memory usage: 16.2+ MB
# None
#                                                 text
# 0  One day, a little girl named Lily found a need...
# 1  Once upon a time, there was a little car named...
# 2  One day, a little fish named Fin was swimming ...
# 3  Once upon a time, in a land full of trees, the...
# 4  Once upon a time, there was a little girl name...

# %%
print(df.isnull().sum())  # Eksik veri sayısını kontrol et
# Out:
# text    230
# dtype: int64

# %%
df.dropna(subset=['text'], inplace=True)
print(df.isnull().sum())  # Tekrar eksik veri kontrolü yapın
# Out:
# text    0
# dtype: int64

# %%
import re

# %%
# Elle stopwords listesi oluşturalım (İngilizce için temel durak kelimeler)
stopwords = ['the', 'and', 'is', 'in', 'to', 'of', 'a', 'that', 'it', 'on', 'for', 'with', 'as', 'by', 'at', 'an', 'this', 'be', 'from', 'or']

# Temizlik fonksiyonunu güncelleyelim
def clean_text(text):
    if isinstance(text, str):  # Sadece string tipindeki değerlere işlem yap
        text = text.lower()  # Tüm metni küçük harfe çevirme
        text = re.sub(r'\d+', '', text)  # Sayıları kaldırma
        text = re.sub(r'[^\w\s]', '', text)  # Noktalama işaretlerini kaldırma
        text = ' '.join([word for word in text.split() if word not in stopwords])  # Durak kelimeleri çıkarma
        return text
    return text  # Eğer metin değilse (örneğin NaN veya sayı), olduğu gibi döndür

# Temizleme fonksiyonunu veri çerçevesine uygulama
df['cleaned_text'] = df['text'].apply(clean_text)

# %%
print(df[['text', 'cleaned_text']].head())
# Out:
#                                                 text  \
# 0  One day, a little girl named Lily found a need...
# 1  Once upon a time, there was a little car named...
# 2  One day, a little fish named Fin was swimming ...
# 3  Once upon a time, in a land full of trees, the...
# 4  Once upon a time, there was a little girl name...
#
#                                         cleaned_text
# 0  one day little girl named lily found needle he...
# 1  once upon time there was little car named beep...
# 2  one day little fish named fin was swimming nea...
# 3  once upon time land full trees there was littl...
# 4  once upon time there was little girl named lil...

# %%
# İlk 5 satırı temizlenmiş metin sütunu ile görüntüleyin
print(df[['text', 'cleaned_text']].head())
# Out:
#                                                 text  \
# 0  One day, a little girl named Lily found a need...
# 1  Once upon a time, there was a little car named...
# 2  One day, a little fish named Fin was swimming ...
# 3  Once upon a time, in a land full of trees, the...
# 4  Once upon a time, there was a little girl name...
#
#                                         cleaned_text
# 0  one day little girl named lily found needle he...
# 1  once upon time there was little car named beep...
# 2  one day little fish named fin was swimming nea...
# 3  once upon time land full trees there was littl...
# 4  once upon time there was little girl named lil...

# %%
import pandas as pd

# CSV dosyasını yükleme
df = pd.read_csv('/kaggle/input/tinystories-narrative-classification/train.csv')

# Veri çerçevesinin ilk birkaç satırını görüntüleme
print(df.head())
# Out:
#                                                 text
# 0  One day, a little girl named Lily found a need...
# 1  Once upon a time, there was a little car named...
# 2  One day, a little fish named Fin was swimming ...
# 3  Once upon a time, in a land full of trees, the...
# 4  Once upon a time, there was a little girl name...

# %%
# 'cleaned_story' sütununun olup olmadığını kontrol etme
if 'cleaned_story' in df.columns:
    # Tekrar eden satırları kaldırma
    df.drop_duplicates(subset='cleaned_story', inplace=True)
    
    # Sonuçları kontrol etme
    print(df.head())
else:
    print("Veri çerçevesinde 'cleaned_story' adlı bir sütun bulunamadı.")
# Out:
# Veri çerçevesinde 'cleaned_story' adlı bir sütun bulunamadı.

# %%
import pandas as pd

# CSV dosyasını yükleme
df = pd.read_csv('/kaggle/input/tinystories-narrative-classification/train.csv')

# Sütun isimlerini görüntüleme
print(df.columns)
# Out:
# Index(['text'], dtype='object')

# %%
import pandas as pd

# Veri setini yükle
data = pd.read_csv("/kaggle/input/tinystories-narrative-classification/train.csv")

# İlk birkaç satırı görüntüleyerek doğru yüklendiğinden emin ol
data.head()
# Out:
#                                                 text
# 0  One day, a little girl named Lily found a need...
# 1  Once upon a time, there was a little car named...
# 2  One day, a little fish named Fin was swimming ...
# 3  Once upon a time, in a land full of trees, the...
# 4  Once upon a time, there was a little girl name...

# %%
# Tekrar eden satırları bul ve kaldır
data_cleaned = data.drop_duplicates()

# Temizlenmiş veri setinin boyutlarını görüntüle
print(f"Orijinal veri seti boyutu: {data.shape}")
print(f"Temizlenmiş veri seti boyutu: {data_cleaned.shape}")
# Out:
# Orijinal veri seti boyutu: (2119719, 1)
# Temizlenmiş veri seti boyutu: (1799249, 1)

# %%
# Veri setindeki sütunları görüntüle
print(data.columns)
# Out:
# Index(['text'], dtype='object')

# %%
print(data_cleaned.isnull().sum())
# Out:
# text    1
# dtype: int64

# %%
# Eksik satırları kaldır
data_cleaned = data_cleaned.dropna()

# Eksik veri olup olmadığını tekrar kontrol et
print(data_cleaned.isnull().sum())
# Out:
# text    0
# dtype: int64

# %%
# Metinleri küçük harfe çevir
data_cleaned['text'] = data_cleaned['text'].str.lower()

# %%
import re

# Fazla boşlukları tek boşluğa indir
data_cleaned['text'] = data_cleaned['text'].apply(lambda x: re.sub(r'\s+', ' ', x).strip())

# %%
# Temizlenmiş verinin ilk birkaç satırını görüntüle
print(data_cleaned['text'].head())
# Out:
# 0    one day, a little girl named lily found a need...
# 1    once upon a time, there was a little car named...
# 2    one day, a little fish named fin was swimming ...
# 3    once upon a time, in a land full of trees, the...
# 4    once upon a time, there was a little girl name...
# Name: text, dtype: object

# %%
# Veri setindeki satır sayısını görmek
print(f"Veri setinde {data_cleaned.shape[0]} satır var.")
# Out:
# Veri setinde 1799248 satır var.

# %%
import tensorflow as tf
print(tf.__version__)  # TensorFlow'un yüklü olup olmadığını ve sürümünü kontrol edin
# Out:
# 2.16.1

# %%
# NaN (boş) değerleri kaldırma
data_cleaned = data_cleaned.dropna(subset=['text'])

# Tüm verileri string'e çevirme ve fazla boşlukları temizleme
data_cleaned['text'] = data_cleaned['text'].astype(str).apply(lambda x: re.sub(r'\s+', ' ', x).strip())

# Temizlenmiş veriyi kontrol et
print(data_cleaned.head())
# Out:
#                                                 text
# 0  one day, a little girl named lily found a need...
# 1  once upon a time, there was a little car named...
# 2  one day, a little fish named fin was swimming ...
# 3  once upon a time, in a land full of trees, the...
# 4  once upon a time, there was a little girl name...

# %%
import pandas as pd

# Veri setinizi yükleyin
df = pd.read_csv('/kaggle/input/tinystories-narrative-classification/train.csv')

# İlk birkaç satırı görüntüleyin
print(df.head())

# Sütun isimlerini görüntüleyin
print(df.columns)
# Out:
#                                                 text
# 0  One day, a little girl named Lily found a need...
# 1  Once upon a time, there was a little car named...
# 2  One day, a little fish named Fin was swimming ...
# 3  Once upon a time, in a land full of trees, the...
# 4  Once upon a time, there was a little girl name...
# Index(['text'], dtype='object')

# %%
import pandas as pd

# Veri setini yükleyin
df = pd.read_csv('/kaggle/input/tinystories-narrative-classification/train.csv')

# Eksik verileri kontrol edin
print(df.isnull().sum())

# Eksik verileri içeren satırları kaldırın
df = df.dropna(subset=['text'])

# Temizlenmiş veri setini kontrol edin
print(df.isnull().sum())
# Out:
# text    230
# dtype: int64
# text    0
# dtype: int64

# %%
print(data_cleaned.head())
# Out:
#                                                 text
# 0  one day, a little girl named lily found a need...
# 1  once upon a time, there was a little car named...
# 2  one day, a little fish named fin was swimming ...
# 3  once upon a time, in a land full of trees, the...
# 4  once upon a time, there was a little girl name...

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import NMF

# Veri setini yükleyin
df = pd.read_csv('/kaggle/input/tinystories-narrative-classification/train.csv')

# Eksik verileri temizleyin
df = df.dropna(subset=['text'])

# Veri setinin küçük bir örneğiyle çalışın (örneğin, ilk 1000 satır)
df_sample = df.sample(1000)

# Metin verisini içeren sütunu alın
texts = df_sample['text'].values

# Metin verisini sayısal verilere dönüştürün
vectorizer = TfidfVectorizer(stop_words='english')
X = vectorizer.fit_transform(texts)

# NMF modelini oluşturun
nmf_model = NMF(n_components=5, random_state=0)
nmf_model.fit(X)

# Konu terimlerini inceleyin
for index, topic in enumerate(nmf_model.components_):
    print(f"Topic #{index}:")
    print([vectorizer.get_feature_names_out()[i] for i in topic.argsort()[-10:]])
# Out:
# Topic #0:
# ['time', 'day', 'little', 'teddy', 'named', 'girl', 'said', 'mom', 'mommy', 'lily']
# Topic #1:
# ['toys', 'billy', 'said', 'named', 'day', 'loved', 'play', 'boy', 'mom', 'timmy']
# Topic #2:
# ['time', 'lucy', 'saw', 'jack', 'day', 'girl', 'little', 'said', 'bird', 'tim']
# Topic #3:
# ['dad', 'like', 'doll', 'car', 'mia', 'mom', 'sara', 'says', 'anna', 'ben']
# Topic #4:
# ['mia', 'sorry', 'did', 'play', 'sam', 'sara', 'said', 'says', 'mom', 'tom']

# %%
import numpy as np

# Her bir hikaye için NMF modelinin konu dağılımlarını al
topic_distributions = nmf_model.transform(X)

# En yüksek olasılığa sahip olan konuyu her hikaye için etiket olarak ata
df_sample['topic_label'] = np.argmax(topic_distributions, axis=1)

# Etiketlenmiş veriyi kontrol edelim
print(df_sample[['text', 'topic_label']].head())
# Out:
#                                                       text  topic_label
# 1713091  Once there was a dependable ostrich who lived ...            2
# 862111   Once upon a time there was a little girl named...            2
# 329338   Once upon a time, there was a caterpillar. He ...            2
# 624989   Sammy was a three year old boy who loved to jo...            2
# 1343124  Once upon a time, there was a little boy named...            4

# %%
# İlk 10 satırı görmek için
print(df_sample[['text', 'topic_label']].head(10))

# Belirli bir konuya ait hikayeleri görmek için (örneğin, 'topic_label' 2 olanlar)
print(df_sample[df_sample['topic_label'] == 2][['text', 'topic_label']])

# Tüm etiketi olan veriyi CSV dosyasına kaydetmek istersen:
df_sample.to_csv('etiketli_veri.csv', index=False)
# Out:
#                                                       text  topic_label
# 1713091  Once there was a dependable ostrich who lived ...            2
# 862111   Once upon a time there was a little girl named...            2
# 329338   Once upon a time, there was a caterpillar. He ...            2
# 624989   Sammy was a three year old boy who loved to jo...            2
# 1343124  Once upon a time, there was a little boy named...            4
# 924195   Once upon a time, there was a little girl name...            0
# 1239874  Once upon a time there was a strong lion that ...            2
# 1707400  One day, Tom was outside playing when he spott...            4
# 1081855  One day, little Aubrey was walking around the ...            2
# 1297118  Ben likes to zoom his toy car on the floor. He...            3
#                                                       text  topic_label
# 1713091  Once there was a dependable ostrich who lived ...            2
# ...

# %%
# Topic Label 0 olan hikayeleri gör
topic_0_stories = df_sample[df_sample['topic_label'] == 0]
print(topic_0_stories[['text', 'topic_label']])

# Topic Label 1 olan hikayeleri gör
topic_1_stories = df_sample[df_sample['topic_label'] == 1]
print(topic_1_stories[['text', 'topic_label']])
# Out:
#                                                       text  topic_label
# 924195   Once upon a time, there was a little girl name...            0
# 1549614  Once upon a time, there was a little girl name...            0
# 1150706  Lily and Max were playing in the snow. They ma...            0
# 761134   Once upon a time, there was a nice girl called...            0
# 1566150  Once upon a time, there was a little girl name...            0
# ...                                                    ...          ...
# 1217205  Once upon a time, there was a little girl name...            0
# 2023605  Once upon a time, there was a little girl name...            0
# 790453   Once upon a time, there was a little girl name...            0
# 1849370  Once upon a time, there was a little girl name...            0
# 303227   Once upon a time, there was a dancer named Lil...            0
#
# [164 rows x 2 columns]
#                                                       text  topic_label
# ...

# %%
import numpy as np
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# Text verisini hazırlayın (girdi verisi olarak kullanacağız)
texts = df_sample['text'].values

# Tokenizer oluşturun
tokenizer = Tokenizer()
tokenizer.fit_on_texts(texts)

# Metinleri sayısal verilere dönüştürün (tokenizasyon)
sequences = tokenizer.texts_to_sequences(texts)

# Verileri aynı uzunluğa getirin (padding işlemi)
maxlen = 100  # Giriş uzunluğu olarak 100 seçtim, bunu ihtiyaca göre artırabilirsiniz
X = pad_sequences(sequences, maxlen=maxlen)

# Konu etiketlerini hedef değerler (output) olarak kullanacağız
y = df_sample['topic_label'].values

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, SimpleRNN, Dense

# Modeli oluşturun
model = Sequential()

# Embedding katmanı (her kelimeyi bir vektör temsil edecek)
model.add(Embedding(input_dim=len(tokenizer.word_index) + 1, output_dim=50))

# RNN katmanı
model.add(SimpleRNN(128, return_sequences=False))

# Çıkış katmanı (5 farklı konu olduğu için)
model.add(Dense(5, activation='softmax'))

# Modeli derleyin
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Modeli eğitin
model.fit(X, y, epochs=10, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - accuracy: 0.4811 - loss: 1.3254 - val_accuracy: 0.6300 - val_loss: 1.1706
# Epoch 2/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.6008 - loss: 1.1670 - val_accuracy: 0.6300 - val_loss: 1.1758
# Epoch 3/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.6186 - loss: 1.0869 - val_accuracy: 0.6300 - val_loss: 1.1589
# Epoch 4/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.6474 - loss: 0.9813 - val_accuracy: 0.6250 - val_loss: 1.1698
# Epoch 5/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.7174 - loss: 0.8202 - val_accuracy: 0.6200 - val_loss: 1.1727
# Epoch 6/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.7569 - loss: 0.7070 - val_accuracy: 0.5900 - val_loss: 1.2767
# Epoch 7/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.8771 - loss: 0.4033 - val_accuracy: 0.5350 - val_loss: 1.3018
# Epoch 8/10
# ...

# %%
# Yeni bir kelime girdisi verelim
new_input = ['dog']

# Tokenizer kullanarak yeni girdiyi sayısal forma dönüştürelim
new_sequence = tokenizer.texts_to_sequences(new_input)
new_sequence = pad_sequences(new_sequence, maxlen=maxlen)

# Modelin tahminini alalım
predicted_topic = model.predict(new_sequence)

# En yüksek olasılıkla tahmin edilen konuyu belirleyelim
predicted_label = np.argmax(predicted_topic)

# O konuya ait bir hikaye seçip yazdıralım
predicted_story = df_sample[df_sample['topic_label'] == predicted_label].sample(1)['text'].values[0]
print(f"Tahmin edilen konu: {predicted_label}, Hikaye: {predicted_story}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step
# Tahmin edilen konu: 2, Hikaye: Tommy was a little boy who liked to play with his toys. He had a lot of cars, trains, and blocks that he kept in his room. Sometimes, he would sneak into his baby sister's room and take some of her toys too. He liked her soft animals and rattles, and he thought she did not need them.
#
# One day, his mom caught him with a pink bunny that belonged to his sister. She was very angry and said, "Tommy, you know you are not supposed to take your sister's toys. They are hers, not yours. You have to give it back and say sorry."
#
# Tommy did not want to give back the bunny. He liked it very much and he wanted to keep it. He said, "No, mom, it is mine. I found it in the crib. She does not play with it. She is too little."
#
# ...

# %%
# Üç kelimelik yeni bir girdi verelim
new_input = ['dog', 'play', 'park']

# Tokenizer kullanarak yeni girdiyi sayısal forma dönüştürelim
new_sequence = tokenizer.texts_to_sequences([' '.join(new_input)])
new_sequence = pad_sequences(new_sequence, maxlen=maxlen)

# Modelin tahminini alalım
predicted_topic = model.predict(new_sequence)

# En yüksek olasılıkla tahmin edilen konuyu belirleyelim
predicted_label = np.argmax(predicted_topic)

# O konuya ait bir hikaye seçip yazdıralım
predicted_story = df_sample[df_sample['topic_label'] == predicted_label].sample(1)['text'].values[0]
print(f"Tahmin edilen konu: {predicted_label}, Hikaye: {predicted_story}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Tahmin edilen konu: 2, Hikaye: One day, the sun was shining very bright in the sky. A little girl named Lucy went outside to play. She saw a smelly sock on the ground. "Yuck!" said Lucy. She picked up the sock and threw it in the trash.
#
# Lucy wanted to cool off, so she went inside her house. She found a fan in her room. The fan blew air on her face and made her feel better. She was very happy.
#
# The next day, Lucy went outside again. The sun was still shining, but the smelly sock was gone. She played all day with her friends. They had lots of fun under the shining sun.

# %%
# 'dog' kelimesini içeren hikayeleri filtrele
filtered_stories = df_sample[df_sample['text'].str.contains('dog', case=False)]

# Eğer bu kelimeyi içeren bir hikaye varsa, rastgele bir tanesini seç
if not filtered_stories.empty:
    predicted_story = filtered_stories.sample(1)['text'].values[0]
    print(f"'dog' kelimesini içeren hikaye: {predicted_story}")
else:
    print("'dog' kelimesini içeren bir hikaye bulunamadı.")
# Out:
# 'dog' kelimesini içeren hikaye: Lily and Ben are friends. They like to play in the yard. The yard has many things. There is a big tree, a swing, a ball, and a dog.
#
# One day, Lily and Ben see something new in the yard. It is a box. The box is big and brown. It has a hole on one side.
#
# "What is that?" Lily asks.
#
# "I don't know. Let's look," Ben says.
#
# They go to the box. They peek inside the hole. They see something shiny and colorful. It is interesting.
#
# "Wow! What is it?" Ben asks.
#
# "I don't know. It looks like a toy," Lily says.
#
# They want to touch it. They reach their hands inside the hole. But then, they hear a noise. It is a loud and scary noise. It comes from the box.
#
# "Roar!" the noise says.
#
# Lily and Ben are afraid. They pull their hands back. They run away from the box. They hide behind the tree.
#
# "What was that?" Lily asks.
#
# "I don't know. It sounded like a lion," Ben says.
#
# ...

# %%
# 'dog' kelimesini içeren hikayeleri filtrele
filtered_stories = df_sample[df_sample['text'].str.contains('dog', case=False)]

# Eğer bu kelimeyi içeren bir hikaye varsa, rastgele bir tanesini seç
if not filtered_stories.empty:
    predicted_story = filtered_stories.sample(1)['text'].values[0]
    print(f"'dog' kelimesini içeren hikaye: {predicted_story}")
else:
    print("'dog' kelimesini içeren bir hikaye bulunamadı.")
# Out:
# 'dog' kelimesini içeren hikaye: Lily likes to ride her bike. She has a pink bike with a bell and a basket. She puts her doll in the basket and rides around the park. She likes to ring the bell and say hello to the people and the dogs.
#
# One day, she sees a big truck in the park. The truck has a cage on the back. Inside the cage, there is a lion. The lion looks sad and angry. He roars and shakes the cage. Lily is scared of the lion. She stops her bike and hides behind a tree.
#
# A man comes out of the truck. He has a cell in his hand. He talks to the cell and says, "I need help. The lion is too wild. He might break the cage." He looks worried and nervous.
#
# Lily wants to help the man and the lion. She remembers that her mom told her that animals like calm voices and gentle touches. She takes her doll out of the basket and walks slowly to the cage. She says to the lion, "Hello, lion. I am Lily. This is my doll. She is soft and nice. Do you want to be friends?"
#
# ...

# %%
model.save('model.h5')

# %%
import pickle
with open('tokenizer.pkl', 'wb') as f:
    pickle.dump(tokenizer, f)

# %%
import os

# Mevcut çalışma dizinindeki dosyaları listele
for file in os.listdir():
    print(file)
# Out:
# tokenizer.pkl
# __notebook__.ipynb
# etiketli_veri.csv
# model.h5

# %%
from IPython.display import FileLink

# Modeli indirin
FileLink(r'./model.h5')

# Tokenizer'ı indirin
FileLink(r'./tokenizer.pkl')
# Out:
# /kaggle/working/tokenizer.pkl

# %%
from IPython.display import FileLink

# Modeli indirin
FileLink(r'./model.h5')
# Out:
# /kaggle/working/model.h5

# %%
from IPython.display import FileLink
FileLink(r'etiketli_veri.csv')
# Out:
# /kaggle/working/etiketli_veri.csv

# %%
import pandas as pd

# Dataset'i oku
df = pd.read_csv('/kaggle/input/tinystories-narrative-classification/train.csv')

# Dataset'i bilgisayara kaydet
df.to_csv('stories.csv', index=False)
